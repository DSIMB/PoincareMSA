# %% [markdown]
# # Poincare Maps projection on Kinases starting from scratch

# %%
import os
import numpy as np
import pandas as pd
#import plotly
#import plotly.express as px
from pplots_new import read_embeddings, plot_embedding, plot_embedding_interactive, rotate, get_colors
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Data preparation

# %% [markdown]
# The user must provide a path to the input file in .mfasta format and path to the output directory for intermediate file storage:

# %%
path_to_PM = "/home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA"
mfasta = path_to_PM+"/examples/globins_try_large/glob_filter4.mfasta" # full path to the input MSA in mfasta format
path_out = path_to_PM+"/examples/globins_try_large_test" # a directory to write resutling files
out_name = "globins_large" # name given to the output files
path_to_figures = "/home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/figures"

# %% [markdown]
# All scripts necessary for data preparation are located in scirpts/data_preparation:

# %%
path_prep_scripts = path_to_PM+"/scripts/prepare_data"

# %% [markdown]
# Data preparation consists in `.mfasta` cleaning according to a gap threshold and translation of each sequence to the PSSM profile:

# %%
gapth = "0.9" # threshold for filtering gapped positions
prep_parameters = path_prep_scripts+" "+mfasta+" "+path_out+" "+out_name+" "+gapth # parameters for data preparation
# print(prep_parameters)
# print(path_prep_scripts+"/create_projection.sh " + prep_parameters)

# %%
os.system(path_prep_scripts+"/create_projection.sh " + prep_parameters)
print("Output files ready for projection are written to: "+path_out+"/fasta"+gapth)
# Out:
# Output files ready for projection are written to: /home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/examples/globins_try_large_test/fasta0.9

# %% [markdown]
# ## Data projection using Poincaré disk
# You can change the parameters of the projection here:

# %%
knn = "5"
gamma = "2.00"
sigma = "1.00"
batchs = "4"
cospca = "0"
epochs = "1000"
seed = "0"

# %% [markdown]
# Then, the following command creates a projection of encoded sequences to a Poincaré disk:

# %%
path_to_build_PM = path_to_PM+"/scripts/build_poincare_map"
pm_command = "python "+path_to_build_PM+"/main.py --input_path "+path_out+"/fasta"+gapth+" --output_path "+path_out+"/projections/ --gamma "+gamma+" --pca "+ cospca+" --epochs "+epochs+" --seed "+seed
print(pm_command)
os.system(pm_command)
# Out:
# python /home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/scripts/build_poincare_map/main.py --input_path /home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/examples/globins_try_large_test/fasta0.9 --output_path /home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/examples/globins_try_large_test/projections/ --gamma 2.00 --pca 0 --epochs 1000 --seed 0
# 0

# %% [markdown]
# Parameters by default are provided in comments. The output files are then written to the following file:

# %%
path_embedding = path_out+"/projections/PM"+knn+"sigma="+sigma+"gamma="+gamma+"cosinepca="+cospca+"_seed"+seed+".csv"
print(path_embedding)
# Out:
# /home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/examples/globins_try_large_test/projections/PM5sigma=1.00gamma=2.00cosinepca=0_seed0.csv

# %% [markdown]
# ## Projection visualization
# One can visualieze the resulting projection using any convenient coloring. To do so, the user shoud provide a `.csv` file with each line corresponding to a protein:

# %%
path_annotation = path_to_PM+"/examples/globins_try_large/globs-species.csv" # path to annotation file
kinase_df = pd.read_csv(path_annotation, index_col = 0)
kinase_df
# Out:
#                                       Short_name                    Species  \
# Name
# Globin C, coelomic                        Globin          Caudina arenicola
# Globin (Fragment)                         Globin      Stegodyphus mimosarum
# Uncharacterized protein          Uncharacterized         Strigamia maritima
# Uncharacterized protein          Uncharacterized            Scylla olivacea
# Uncharacterized protein          Uncharacterized            Scylla olivacea
# ...                                          ...                        ...
# Uncharacterized protein          Uncharacterized            Roseiflexus sp.
# Uncharacterized protein          Uncharacterized  Herpetosiphon aurantiacus
# Uncharacterized protein          Uncharacterized            Pseudomonas sp.
# Globin coupled histidine kinase           Globin         Serratia fonticola
# Globin coupled histidine kinase           Globin            Pseudomonas sp.
#
#                                  Short_species
# Name
# Globin C, coelomic                     Caudina
# Globin (Fragment)                  Stegodyphus
# Uncharacterized protein              Strigamia
# Uncharacterized protein                 Scylla
# Uncharacterized protein                 Scylla
# ...                                        ...
# Uncharacterized protein            Roseiflexus
# Uncharacterized protein          Herpetosiphon
# Uncharacterized protein            Pseudomonas
# Globin coupled histidine kinase       Serratia
# Globin coupled histidine kinase    Pseudomonas
#
# [3158 rows x 3 columns]

# %% [markdown]
# A user can also create a custom color palette:

# %%
# construction of palette 
#kinase_palette = {-1 : "#c7c7c7", "OTHER": "#c7c7c7", "None" :"#c7c7c7", "NA" : "#c7c7c7", "Uncharacterized" : "#c7c7c7", "root": "#000000",
#                 "TYR": "#bd065f", "CMGC": "#d5c203", "TKL": "#997e73","STE": "#80b412", # kinase groups 
#                 "CK1": "#0dbae9", "AGC": "#00bba1", "CAMK":  "#1f6ed4", "NEK": "#8ce4fa", "RGC":"#f59a62"}

# %%
df = read_embeddings(path_embedding, path_annotation, withroot=False)
# Out:
# result:                    pm1       pm2                             Name  \
# proteins_id
# 1           -0.024999  0.535806               Globin C, coelomic
# 2           -0.265485  0.458785                Globin (Fragment)
# 3           -0.157738  0.380762          Uncharacterized protein
# 4           -0.114742  0.350055          Uncharacterized protein
# 5           -0.114837  0.349793          Uncharacterized protein
# ...               ...       ...                              ...
# 3154        -0.816356 -0.560106          Uncharacterized protein
# 3155        -0.814966 -0.560571          Uncharacterized protein
# 3156        -0.813099 -0.559961          Uncharacterized protein
# 3157        -0.818654 -0.558018  Globin coupled histidine kinase
# 3158        -0.813948 -0.558028  Globin coupled histidine kinase
#
#                   Short_name                    Species  Short_species
# proteins_id
# 1                     Globin          Caudina arenicola        Caudina
# 2                     Globin      Stegodyphus mimosarum    Stegodyphus
# 3            Uncharacterized         Strigamia maritima      Strigamia
# 4            Uncharacterized            Scylla olivacea         Scylla
# 5            Uncharacterized            Scylla olivacea         Scylla
# ...                      ...                        ...            ...
# 3154         Uncharacterized            Roseiflexus sp.    Roseiflexus
# 3155         Uncharacterized  Herpetosiphon aurantiacus  Herpetosiphon
# 3156         Uncharacterized            Pseudomonas sp.    Pseudomonas
# 3157                  Globin         Serratia fonticola       Serratia
# 3158                  Globin            Pseudomonas sp.    Pseudomonas
#
# [3158 rows x 6 columns]

# %% [markdown]
# Here follow several examples of kinase family visualization.

# %% [markdown]
# ## Color by globin name

# %%
# construction of palette 
globin_palette = {-1 : "#c7c7c7", "OTHER": "#c7c7c7", "NA" : "#c7c7c7", "Uncharacterized" : "#c7c7c7", "root": "#000000",
                 "Nematostella": "#ad288b", "Amphimedon": "#fdb7fd", "Micromonas": "#4d9b03", "Saccoglossus":"#b0ffe8", "Trichoplax":"#e9bd6b" } 

globin_others_eukaryota = ["Amphimedon", # porifera 
 "Saccoglossus", # hemichordata
 "Trichoplax", # placozoa
 "Micromonas", # viridiplantae
 "Nematostella" ] # cnidaria  
 
globin_arthropoda = ["Stegodyphus", "Strigamia", "Scylla", "Carcinus",  "Ixodes", "Zootermopsis", "Coptotermes","Oryctes", "Tetranychus", 
                     "Acyrthosiphon", "Nemastomella","Apis","Solenopsis", "Habropoda", "Fopius", "Cerapachys", "Camponotus", "Nasonia", 
                     "Acromyrmex", "Tribolium", "Sarcoptes", "Lutzomyia", "Rhodnius", "Triatoma", "Cherax", "Chironomus", "Polypedilum", 
                     "Pediculus", "Daphnia", "Harpegnathos", "Artemia", "Parartemia", "Lepeophtheirus", "Glossina", "Operophtera"] 
  
globin_mollusca = ["Arion", "Crassostrea", "Lottia", "Anadara", "Spisula", "Barbatia", "Nassarius", "Cerithidea", "Nerita", "Phacoides",
                   "Octopus", "Biomphalaria"] 
globin_annelida = ["Capitella", "Metaphire"]  
globin_chordata = ["Scleropages", "Branchiostoma", "Xenopus", "Oreochromis", "Nothobranchius", "Gasterosteus", "Bos", "Iguana", "Oryzias", 
                   "Anas", "Tetraodon", "Takifugu", "Xiphophorus", "Larimichthys", "Oncorhynchus", "Alligator", "Astyanax", "Latimeria",
                   "Ictalurus", "Chaenocephalus", "Danio", "Cyprinus", "Callorhinchus", "Lepisosteus", "Chelonia", "Poecilia", "Ciona", 
                   "Petromyzon", "Lethenteron", "Cavia", "Scalopus", "Neotoma", "Pelodiscus","Fundulus", "Oryctolagus", "Anolis",
                   "Salmo", "Amazona", "Ornithorhynchus", "Sarcophilus", "Gallus", "Nomascus", "Tupaia"] 
 
globin_echinodermata = ["Caudina", "Strongylocentrotus", "Hemipholis", "Ophiactis"] 
globin_bacteria = ["Gemmatirosa", "Halothiobacillus"] 
globin_nematoda = ["Ancylostoma", "Necator", "Caenorhabditis", "Haemonchus", "Ascaris", "Trichinella", "Globodera", "Strongyloides", "Angiostrongylus"] 
globin_fungi = ["Blastobotrys", "Cyberlindnera"] 


#globin_palette.update(dict.fromkeys(globin_others_eukaryota, "#22ba69")) 
globin_palette.update(dict.fromkeys(globin_arthropoda, "#0b237c"))
globin_palette.update(dict.fromkeys(globin_mollusca, "#512ff8")) #512ff8 401bf9
globin_palette.update(dict.fromkeys(globin_annelida, "#a191f3"))
globin_palette.update(dict.fromkeys(globin_chordata, "#26c9d9"))
globin_palette.update(dict.fromkeys(globin_echinodermata, "#086b75"))
globin_palette.update(dict.fromkeys(globin_bacteria, "#f10000"))
globin_palette.update(dict.fromkeys(globin_nematoda, "#5d78e3"))
globin_palette.update(dict.fromkeys(globin_fungi, "#a0e361"))

# %%
trace1 = plot_embedding_interactive(df, 
                                    labels_name = 'Short_name',#'1_Group',#'2_Gene', 
                                    show_text=True, 
                                    color_palette = globin_palette,
                                    title = "Poinicaré Map projection colored by kinase groups", 
                                    fontsize = 10,
                              )
trace1.write_image(path_to_figures+"/Globins_Short_name.pdf")
trace1.show()
# Out:
# Index(['Name', 'Short_name', 'Species', 'Short_species'], dtype='object')
# <div>                            <div id="3c1b9366-4709-4e11-906f-b8c0931dc1dd" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c1b9366-4709-4e11-906f-b8c0931dc1dd")) {                    Plotly.newPlot(                        "3c1b9366-4709-4e11-906f-b8c0931dc1dd",                        [{"customdata":[["Globin C, coelomic","Globin","Caudina arenicola","Caudina"],["Globin (Fragment)","Globin","Stegodyphus mimosarum","Stegodyphus"],["Globin","Globin","Zootermopsis nevadensis","Zootermopsis"],["Globin like protein (Fragment)","Globin","Coptotermes formosanus","Coptotermes"],["Globin like Protein","Globin","Tribolium castaneum","Tribolium"],["Globin (Fragment)","Globin","Anoplophora glabripennis","Anoplophora"],["Globin","Globin","Branchiostoma floridae","Branchiostoma"],["Globin 1","Globin","Apis mellifera","Apis"],["Globin","Globin","Habropoda laboriosa","Habropoda"],["Globin","Globin","Camponotus floridanus","Camponotus"],["Globin like Protein","Globin","Tribolium castaneum","Tribolium"],["Globin CTT VIIB 8, putative","Globin","Pediculus humanus","Pediculus"],["Globin","Globin","Daphnia magna","Daphnia"],["Globin","Globin","Starkeya novella","Starkeya"],["Globin","Globin","Ectocarpus siliculosus","Ectocarpus"],["Globin","Globin","Xanthobacter autotrophicus","Xanthobacter"],["Globin","Globin","gamma proteobacterium","gamma"],["Globin domain protein","Globin","Acidithiobacillus ferrooxidans","Acidithiobacillus"],["Globin","Globin","Bradyrhizobium manausense","Bradyrhizobium"],["Globin","Globin","Rhodopseudomonas palustris","Rhodopseudomonas"],["Globin","Globin","Rhizobium sp.","Rhizobium"],["Globin","Globin","Citreicella sp.","Citreicella"],["Globin","Globin","Fibrella aestuarina","Fibrella"],["Globin","Globin","Gemmatirosa kalamazoonesis","Gemmatirosa"],["Globin","Globin","Rhodoplanes sp.","Rhodoplanes"],["Globin","Globin","Aeromonas media","Aeromonas"],["Globin","Globin","Rhodopseudomonas palustris","Rhodopseudomonas"],["Globin","Globin","Opitutus terrae","Opitutus"],["Globin like protein","Globin","Rhizobium sp.","Rhizobium"],["Globin","Globin","Rhodobacterales bacterium","Rhodobacterales"],["Globin","Globin","Gemmatirosa kalamazoonesis","Gemmatirosa"],["Globin","Globin","Runella slithyformis","Runella"],["Globin","Globin","Leptospira kmetyi","Leptospira"],["Globin","Globin","Chloroflexi bacterium","Chloroflexi"],["Globin","Globin","Methylobacterium nodulans","Methylobacterium"],["Globin","Globin","Branchiostoma floridae","Branchiostoma"],["Globin 2 A chain","Globin","Anadara inaequivalvis","Anadara"],["Globin 2 B chain","Globin","Anadara inaequivalvis","Anadara"],["Globin 2B","Globin","Anadara trapezia","Anadara"],["Globin domain containing protein","Globin","Flavobacterium daejeonense","Flavobacterium"],["Globin","Globin","Shewanella sediminis","Shewanella"],["Globin","Globin","Shewanella woodyi","Shewanella"],["Globin","Globin","Polypedilum nubifer","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin 2","Globin","Chironomus riparius","Chironomus"],["Globin","Globin","Polypedilum nubifer","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum nubifer","Polypedilum"],["Globin","Globin","Polypedilum nubifer","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],["Globin","Globin","Polypedilum vanderplanki","Polypedilum"],[" ...

# %% [markdown]
# You can highlight several points by using plotly iterface. Provide the corresponding column name in `second_labels_name` and a list of labels to show in `labels_text`:

# %%
trace2 = plot_embedding_interactive(df, 
                                    labels_name = '1_Group',#'1_Group',#'2_Gene', 
                                    show_text=True, 
                                    color_palette = kinase_palette,
                                    title = "Poinicaré Map projection colored by kinase groups", 
                                    fontsize = 10,
                                    second_labels_name = "4_Uni_entry", 
                                    #labels_text = ["ST17B_HUMAN", "MYLK2_HUMAN", "KALRN_HUMAN"]
                                    labels_text = ["CLK3_HUMAN", "SRPK3_HUMAN", "HIPK1_HUMAN","CSK22_HUMAN"] # some CMGC kinase
                                    #second_labels_name = "2_Gene",
                                    #labels_text = ["RPS6KA1_1", "RPS6KA2_1", "RPS6KA5_1", "RPS6KB2", "RPS6KA1_2", "RPS6KA2_2",  "RPS6KA3_2",  "RPS6KA5_2"] # some sequences of AGC first domain and CAMK second domain (mentionned in the article) to label
                                    
                              )
trace2.show()
# Out:
# Index(['1_Group', '2_Gene', '3_HGNC', '4_Uni_entry', '5_Uni_acc',
#        '6_Domain_begin', '7_Domain_end', '8_Domain_length',
#        '9_Largest_insert_length', '10_PDB_validation',
#        '11_Conformational_state', '12_Dihedral_state', '13_Group_in_Uni',
#        '14_Group_in_Manning', '15_Synonymn', 'evo_distance', 'decile_domain'],
#       dtype='object')
# <div>                            <div id="369c9ff4-6176-4f41-9aab-2147cdda1241" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("369c9ff4-6176-4f41-9aab-2147cdda1241")) {                    Plotly.newPlot(                        "369c9ff4-6176-4f41-9aab-2147cdda1241",                        [{"customdata":[["AGC","AKT1","HGNC:391","AKT1_HUMAN","P31749",150,408,259,9,"6NPZB","DFGin","BLAminus","AGC","AGC","PKB,RAC",1.2082659799999995,2],["AGC","AKT2","HGNC:392","AKT2_HUMAN","P31751",152,409,258,9,"3E8DB","DFGin","BLAminus","AGC","AGC",null,1.20831188,2],["AGC","AKT3","HGNC:393","AKT3_HUMAN","Q9Y243",148,405,258,9,null,null,null,"AGC","AGC","PKBG",1.1834633399999996,2],["AGC","CDC42BPA","HGNC:1737","MRCKA_HUMAN","Q5VT25",77,343,267,14,null,null,null,"AGC","AGC","KIAA0451",1.39911886,5],["AGC","CDC42BPB","HGNC:1738","MRCKB_HUMAN","Q9Y5S2",76,342,267,14,"5OTFA","DFGin","BLAminus","AGC","AGC","KIAA1124",1.40621273,5],["AGC","CDC42BPG","HGNC:29829","MRCKG_HUMAN","Q6DT37",71,337,267,14,null,null,null,"AGC","AGC","DMPK2",1.40589533,5],["AGC","CIT","HGNC:1985","CTRO_HUMAN","O14578",97,360,264,13,null,null,null,"AGC","AGC","CRIK,KIAA0949,STK21",1.53724126,4],["AGC","DMPK","HGNC:2933","DMPK_HUMAN","Q09013",71,339,269,14,"2VD5A","DFGin","BLAminus","AGC","AGC","DM1PK,MDPK",1.41225394,5],["AGC","GRK1","HGNC:10013","GRK1_HUMAN","Q15835",190,455,266,9,null,null,null,"AGC","AGC","RHOK",1.60739569,5],["AGC","GRK2","HGNC:289","ARBK1_HUMAN","P25098",191,453,263,9,"5UVCA","DFGin","BLAminus","AGC","AGC","ADRBK1,BARK,BARK1",1.5647884,4],["AGC","GRK3","HGNC:290","ARBK2_HUMAN","P35626",191,453,263,9,null,null,null,"AGC","AGC","ADRBK2,BARK2",1.57174179,4],["AGC","GRK4","HGNC:4543","GRK4_HUMAN","P32298",187,449,263,9,"4YHJB","DFGin","BLAminus","AGC","AGC","GPRK2L,GPRK4",1.56332706,4],["AGC","GRK5","HGNC:4544","GRK5_HUMAN","P34947",186,448,263,9,"4TNDA","DFGin","BLAminus","AGC","AGC","GPRK5",1.5746367799999998,4],["AGC","GRK6","HGNC:4545","GRK6_HUMAN","P43250",186,448,263,9,"2ACXA","DFGin","BLAminus","AGC","AGC","GPRK6",1.47702936,4],["AGC","GRK7","HGNC:17031","GRK7_HUMAN","Q8WTQ7",191,454,264,10,null,null,null,"AGC","AGC","GPRK7",1.67021082,4],["AGC","LATS1","HGNC:6514","LATS1_HUMAN","O95835",705,1010,306,48,null,null,null,"AGC","AGC","WARTS",1.2609807400000002,9],["AGC","LATS2","HGNC:6515","LATS2_HUMAN","Q9NRM7",668,973,306,48,null,null,null,"AGC","AGC","KPM",1.26007137,9],["AGC","MAST1","HGNC:19034","MAST1_HUMAN","Q9Y2H9",374,647,274,16,null,null,null,"AGC","AGC","KIAA0973,SAST",1.23394107,6],["AGC","MAST2","HGNC:19035","MAST2_HUMAN","Q6P0Q8",512,785,274,16,null,null,null,"AGC","AGC","KIAA0807,MAST205",1.25017333,6],["AGC","MAST3","HGNC:19036","MAST3_HUMAN","O60307",367,640,274,16,null,null,null,"AGC","AGC","KIAA0561",1.22755256,6],["AGC","MAST4","HGNC:19037","MAST4_HUMAN","O15021",570,843,274,16,null,null,null,"AGC","AGC","KIAA0303",1.25000298,6],["AGC","MASTL","HGNC:19042","GWL_HUMAN","Q96GX5",35,835,801,548,"5LOHA","DFGin","BLAplus","AGC","AGC","GW,GWL,THC2",1.3154757,9],["AGC","PDPK1","HGNC:8816","PDPK1_HUMAN","O15530",82,342,261,9,"2BIYA","DFGin","BLAminus","AGC","AGC","PDK1",1.48434279,3],["AGC","PDPK2P","HGNC:49897","PDPK2_HUMAN","Q6A1A2",55,315,261,9,null,null,null,"AGC","AGC","PDPK2",1.48434279,3],["AGC","PKN1","HGNC:9405","PKN1_HUMAN","Q16512",615,874,260,9,"4OTGA","DFGin","ABAminus","AGC","AGC","PAK1,PKN,PRK1,PRKCL1",1.34335487,3],["AGC","PKN2","HGNC:9406","PKN2_HUMAN","Q16513",657,916,260,9,"4CRSA","DFGin","BLAminus","AGC","AGC","PRK2,PRKCL2",1.3343051,3],["AGC","PKN3","HGNC:17999","PKN3_HUMAN","Q6P5Z2",559,818,260,9,null,null,null,"AGC","AGC","PKNBETA",1.3670749599999998,3],["AGC","PRKACA","HGNC:9380","KAPCA_HUMAN","P17612",44,298,255,9,"6C0UA","DFGin","BLAminus","AGC","AGC","PKACA",1.20344294,1],["AGC"," ...

# %% [markdown]
# You can also compare different colorings by assigning the `labels_name` variable a name of the desired column. Here we compare the kinase group coloring proposed in the article to the Uniprot name of kinase:

# %%
trace3 = plot_embedding_interactive(df, 
                                    labels_name = '13_Group_in_Uni',#'1_Group',#'2_Gene', 
                                    show_text=True, 
                                    color_palette = kinase_palette,
                                    title = "PM projection on kinases by kinase groups in Uniprot - KNN 5 gamma 3 batchsize 4 epochs 1000",
                                    fontsize = 10,
                                    )
trace3.write_image(path_to_figures+"/Kinases_by_UniGroup.pdf")
trace3.show()
# Out:
# Index(['1_Group', '2_Gene', '3_HGNC', '4_Uni_entry', '5_Uni_acc',
#        '6_Domain_begin', '7_Domain_end', '8_Domain_length',
#        '9_Largest_insert_length', '10_PDB_validation',
#        '11_Conformational_state', '12_Dihedral_state', '13_Group_in_Uni',
#        '14_Group_in_Manning', '15_Synonymn', 'evo_distance', 'decile_domain'],
#       dtype='object')
# <div>                            <div id="9e2537ab-3516-4f37-abb9-44bc2fd515ad" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e2537ab-3516-4f37-abb9-44bc2fd515ad")) {                    Plotly.newPlot(                        "9e2537ab-3516-4f37-abb9-44bc2fd515ad",                        [{"customdata":[["AGC","AKT1","HGNC:391","AKT1_HUMAN","P31749",150,408,259,9,"6NPZB","DFGin","BLAminus","AGC","AGC","PKB,RAC",1.2082659799999995,2],["AGC","AKT2","HGNC:392","AKT2_HUMAN","P31751",152,409,258,9,"3E8DB","DFGin","BLAminus","AGC","AGC",null,1.20831188,2],["AGC","AKT3","HGNC:393","AKT3_HUMAN","Q9Y243",148,405,258,9,null,null,null,"AGC","AGC","PKBG",1.1834633399999996,2],["AGC","CDC42BPA","HGNC:1737","MRCKA_HUMAN","Q5VT25",77,343,267,14,null,null,null,"AGC","AGC","KIAA0451",1.39911886,5],["AGC","CDC42BPB","HGNC:1738","MRCKB_HUMAN","Q9Y5S2",76,342,267,14,"5OTFA","DFGin","BLAminus","AGC","AGC","KIAA1124",1.40621273,5],["AGC","CDC42BPG","HGNC:29829","MRCKG_HUMAN","Q6DT37",71,337,267,14,null,null,null,"AGC","AGC","DMPK2",1.40589533,5],["AGC","CIT","HGNC:1985","CTRO_HUMAN","O14578",97,360,264,13,null,null,null,"AGC","AGC","CRIK,KIAA0949,STK21",1.53724126,4],["AGC","DMPK","HGNC:2933","DMPK_HUMAN","Q09013",71,339,269,14,"2VD5A","DFGin","BLAminus","AGC","AGC","DM1PK,MDPK",1.41225394,5],["AGC","GRK1","HGNC:10013","GRK1_HUMAN","Q15835",190,455,266,9,null,null,null,"AGC","AGC","RHOK",1.60739569,5],["AGC","GRK2","HGNC:289","ARBK1_HUMAN","P25098",191,453,263,9,"5UVCA","DFGin","BLAminus","AGC","AGC","ADRBK1,BARK,BARK1",1.5647884,4],["AGC","GRK3","HGNC:290","ARBK2_HUMAN","P35626",191,453,263,9,null,null,null,"AGC","AGC","ADRBK2,BARK2",1.57174179,4],["AGC","GRK4","HGNC:4543","GRK4_HUMAN","P32298",187,449,263,9,"4YHJB","DFGin","BLAminus","AGC","AGC","GPRK2L,GPRK4",1.56332706,4],["AGC","GRK5","HGNC:4544","GRK5_HUMAN","P34947",186,448,263,9,"4TNDA","DFGin","BLAminus","AGC","AGC","GPRK5",1.5746367799999998,4],["AGC","GRK6","HGNC:4545","GRK6_HUMAN","P43250",186,448,263,9,"2ACXA","DFGin","BLAminus","AGC","AGC","GPRK6",1.47702936,4],["AGC","GRK7","HGNC:17031","GRK7_HUMAN","Q8WTQ7",191,454,264,10,null,null,null,"AGC","AGC","GPRK7",1.67021082,4],["AGC","LATS1","HGNC:6514","LATS1_HUMAN","O95835",705,1010,306,48,null,null,null,"AGC","AGC","WARTS",1.2609807400000002,9],["AGC","LATS2","HGNC:6515","LATS2_HUMAN","Q9NRM7",668,973,306,48,null,null,null,"AGC","AGC","KPM",1.26007137,9],["AGC","MAST1","HGNC:19034","MAST1_HUMAN","Q9Y2H9",374,647,274,16,null,null,null,"AGC","AGC","KIAA0973,SAST",1.23394107,6],["AGC","MAST2","HGNC:19035","MAST2_HUMAN","Q6P0Q8",512,785,274,16,null,null,null,"AGC","AGC","KIAA0807,MAST205",1.25017333,6],["AGC","MAST3","HGNC:19036","MAST3_HUMAN","O60307",367,640,274,16,null,null,null,"AGC","AGC","KIAA0561",1.22755256,6],["AGC","MAST4","HGNC:19037","MAST4_HUMAN","O15021",570,843,274,16,null,null,null,"AGC","AGC","KIAA0303",1.25000298,6],["AGC","MASTL","HGNC:19042","GWL_HUMAN","Q96GX5",35,835,801,548,"5LOHA","DFGin","BLAplus","AGC","AGC","GW,GWL,THC2",1.3154757,9],["AGC","PDPK1","HGNC:8816","PDPK1_HUMAN","O15530",82,342,261,9,"2BIYA","DFGin","BLAminus","AGC","AGC","PDK1",1.48434279,3],["AGC","PDPK2P","HGNC:49897","PDPK2_HUMAN","Q6A1A2",55,315,261,9,null,null,null,"AGC","AGC","PDPK2",1.48434279,3],["AGC","PKN1","HGNC:9405","PKN1_HUMAN","Q16512",615,874,260,9,"4OTGA","DFGin","ABAminus","AGC","AGC","PAK1,PKN,PRK1,PRKCL1",1.34335487,3],["AGC","PKN2","HGNC:9406","PKN2_HUMAN","Q16513",657,916,260,9,"4CRSA","DFGin","BLAminus","AGC","AGC","PRK2,PRKCL2",1.3343051,3],["AGC","PKN3","HGNC:17999","PKN3_HUMAN","Q6P5Z2",559,818,260,9,null,null,null,"AGC","AGC","PKNBETA",1.3670749599999998,3],["AGC","PRKACA","HGNC:9380","KAPCA_HUMAN","P17612",44,298,255,9,"6C0UA","DFGin","BLAminus","AGC","AGC","PKACA",1.20344294,1],["AGC"," ...

# %% [markdown]
# ...and to the classification provided in Manning et al. study:

# %%
trace4 = plot_embedding_interactive(df, 
                                    labels_name = '14_Group_in_Manning',#'1_Group',#'2_Gene', 
                                    show_text=True, 
                                    color_palette = kinase_palette,
                                    second_labels_name = "2_Gene", 
                                    title = "Poincaré Maps projection by kinases groups according to Manning",
                                    fontsize = 10, 
                                    #labels_text = ["MAP3K7, MAP3K9", "MAP3K10", "MAP3K11", "MAP3K12", "MAP3K13", "MAP3K20", "MAP3K21"] # STE dans TKL
                                    #labels_text = ["AURKA", "AURKB", "AURKC", "CAMKK1", "CAMKK2", "PLK1", "PLK2", "PLK3", "PLK4"] # 10 kinases pourraient être CAMK
                                    
                              )
trace4.write_image(path_to_figures+"/Kinases_by_ManningGroup.pdf")
trace4.show()
# Out:
# Index(['1_Group', '2_Gene', '3_HGNC', '4_Uni_entry', '5_Uni_acc',
#        '6_Domain_begin', '7_Domain_end', '8_Domain_length',
#        '9_Largest_insert_length', '10_PDB_validation',
#        '11_Conformational_state', '12_Dihedral_state', '13_Group_in_Uni',
#        '14_Group_in_Manning', '15_Synonymn', 'evo_distance', 'decile_domain'],
#       dtype='object')
# <div>                            <div id="7d17e55e-c7ed-4ec0-9f21-af6e62bb3362" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d17e55e-c7ed-4ec0-9f21-af6e62bb3362")) {                    Plotly.newPlot(                        "7d17e55e-c7ed-4ec0-9f21-af6e62bb3362",                        [{"customdata":[["AGC","AKT1","HGNC:391","AKT1_HUMAN","P31749",150,408,259,9,"6NPZB","DFGin","BLAminus","AGC","AGC","PKB,RAC",1.2082659799999995,2],["AGC","AKT2","HGNC:392","AKT2_HUMAN","P31751",152,409,258,9,"3E8DB","DFGin","BLAminus","AGC","AGC",null,1.20831188,2],["AGC","AKT3","HGNC:393","AKT3_HUMAN","Q9Y243",148,405,258,9,null,null,null,"AGC","AGC","PKBG",1.1834633399999996,2],["AGC","CDC42BPA","HGNC:1737","MRCKA_HUMAN","Q5VT25",77,343,267,14,null,null,null,"AGC","AGC","KIAA0451",1.39911886,5],["AGC","CDC42BPB","HGNC:1738","MRCKB_HUMAN","Q9Y5S2",76,342,267,14,"5OTFA","DFGin","BLAminus","AGC","AGC","KIAA1124",1.40621273,5],["AGC","CDC42BPG","HGNC:29829","MRCKG_HUMAN","Q6DT37",71,337,267,14,null,null,null,"AGC","AGC","DMPK2",1.40589533,5],["AGC","CIT","HGNC:1985","CTRO_HUMAN","O14578",97,360,264,13,null,null,null,"AGC","AGC","CRIK,KIAA0949,STK21",1.53724126,4],["AGC","DMPK","HGNC:2933","DMPK_HUMAN","Q09013",71,339,269,14,"2VD5A","DFGin","BLAminus","AGC","AGC","DM1PK,MDPK",1.41225394,5],["AGC","GRK1","HGNC:10013","GRK1_HUMAN","Q15835",190,455,266,9,null,null,null,"AGC","AGC","RHOK",1.60739569,5],["AGC","GRK2","HGNC:289","ARBK1_HUMAN","P25098",191,453,263,9,"5UVCA","DFGin","BLAminus","AGC","AGC","ADRBK1,BARK,BARK1",1.5647884,4],["AGC","GRK3","HGNC:290","ARBK2_HUMAN","P35626",191,453,263,9,null,null,null,"AGC","AGC","ADRBK2,BARK2",1.57174179,4],["AGC","GRK4","HGNC:4543","GRK4_HUMAN","P32298",187,449,263,9,"4YHJB","DFGin","BLAminus","AGC","AGC","GPRK2L,GPRK4",1.56332706,4],["AGC","GRK5","HGNC:4544","GRK5_HUMAN","P34947",186,448,263,9,"4TNDA","DFGin","BLAminus","AGC","AGC","GPRK5",1.5746367799999998,4],["AGC","GRK6","HGNC:4545","GRK6_HUMAN","P43250",186,448,263,9,"2ACXA","DFGin","BLAminus","AGC","AGC","GPRK6",1.47702936,4],["AGC","GRK7","HGNC:17031","GRK7_HUMAN","Q8WTQ7",191,454,264,10,null,null,null,"AGC","AGC","GPRK7",1.67021082,4],["AGC","LATS1","HGNC:6514","LATS1_HUMAN","O95835",705,1010,306,48,null,null,null,"AGC","AGC","WARTS",1.2609807400000002,9],["AGC","LATS2","HGNC:6515","LATS2_HUMAN","Q9NRM7",668,973,306,48,null,null,null,"AGC","AGC","KPM",1.26007137,9],["AGC","MAST1","HGNC:19034","MAST1_HUMAN","Q9Y2H9",374,647,274,16,null,null,null,"AGC","AGC","KIAA0973,SAST",1.23394107,6],["AGC","MAST2","HGNC:19035","MAST2_HUMAN","Q6P0Q8",512,785,274,16,null,null,null,"AGC","AGC","KIAA0807,MAST205",1.25017333,6],["AGC","MAST3","HGNC:19036","MAST3_HUMAN","O60307",367,640,274,16,null,null,null,"AGC","AGC","KIAA0561",1.22755256,6],["AGC","MAST4","HGNC:19037","MAST4_HUMAN","O15021",570,843,274,16,null,null,null,"AGC","AGC","KIAA0303",1.25000298,6],["AGC","MASTL","HGNC:19042","GWL_HUMAN","Q96GX5",35,835,801,548,"5LOHA","DFGin","BLAplus","AGC","AGC","GW,GWL,THC2",1.3154757,9],["AGC","PDPK1","HGNC:8816","PDPK1_HUMAN","O15530",82,342,261,9,"2BIYA","DFGin","BLAminus","AGC","AGC","PDK1",1.48434279,3],["AGC","PDPK2P","HGNC:49897","PDPK2_HUMAN","Q6A1A2",55,315,261,9,null,null,null,"AGC","AGC","PDPK2",1.48434279,3],["AGC","PKN1","HGNC:9405","PKN1_HUMAN","Q16512",615,874,260,9,"4OTGA","DFGin","ABAminus","AGC","AGC","PAK1,PKN,PRK1,PRKCL1",1.34335487,3],["AGC","PKN2","HGNC:9406","PKN2_HUMAN","Q16513",657,916,260,9,"4CRSA","DFGin","BLAminus","AGC","AGC","PRK2,PRKCL2",1.3343051,3],["AGC","PKN3","HGNC:17999","PKN3_HUMAN","Q6P5Z2",559,818,260,9,null,null,null,"AGC","AGC","PKNBETA",1.3670749599999998,3],["AGC","PRKACA","HGNC:9380","KAPCA_HUMAN","P17612",44,298,255,9,"6C0UA","DFGin","BLAminus","AGC","AGC","PKACA",1.20344294,1],["AGC"," ...
