# %%
import pandas as pd
from pplots import read_embeddings, plot_embedding, plot_embedding_interactive, rotate, get_colors

# %matplotlib inline

# %%
#path_embedding = "/home/lavande/galochkina/SCIENCE/POINCARE/Kinases/test_epoch1000/PM3sigma=1.00gamma=1.00cosinepca=0_seed0.csv"
#path_embedding = "/home/lavande/galochkina/SCIENCE/POINCARE/Kinases/PM3sigma=1.00gamma=1.00cosinepca=0_seed0.csv"
path_embedding = "/home/lavande/galochkina/SCIENCE/POINCARE/Kinases/TEST/PM5sigma=1.00gamma=2.00cosinepca=0_seed0.csv"
path_annotation = "/home/lavande/galochkina/SCIENCE/POINCARE/PoincareMSA/examples/kinases/kinase_group.csv"

# %%
df = read_embeddings(path_embedding, path_annotation, withroot=True) 
df = df.fillna("NA")
print(df)
# Out:
# result:                    pm1       pm2 1_Group    2_Gene      3_HGNC  4_Uni_entry  \
# proteins_id
# 0            0.000000  0.000000    root      root        root         root
# 1            0.903290  0.053931     AGC      AKT1    HGNC:391   AKT1_HUMAN
# 2            0.895974  0.053077     AGC      AKT2    HGNC:392   AKT2_HUMAN
# 3            0.892736  0.030665     AGC      AKT3    HGNC:393   AKT3_HUMAN
# 4           -0.816839  0.456610     AGC  CDC42BPA   HGNC:1737  MRCKA_HUMAN
# ...               ...       ...     ...       ...         ...          ...
# 493         -0.295158 -0.475300     TYR    TYK2_1  HGNC:12440   TYK2_HUMAN
# 494          0.200527 -0.821358     TYR    TYK2_2  HGNC:12440   TYK2_HUMAN
# 495         -0.525353  0.000614     TYR     TYRO3  HGNC:12446  TYRO3_HUMAN
# 496         -0.629044 -0.356421     TYR      YES1  HGNC:12841    YES_HUMAN
# 497         -0.617711 -0.600680     TYR     ZAP70  HGNC:12858  ZAP70_HUMAN
#
# ...

# %%
#print(df['11_Conformational_state'])
trace1 = plot_embedding_interactive(df, 
                                    labels_name = '11_Conformational_state',#'1_Group',#'2_Gene', 
                                    show_text=True,
                                    labels_text = ['PIK3R4']
                              )
trace1.show()
# Out:
# Index(['1_Group', '2_Gene', '3_HGNC', '4_Uni_entry', '5_Uni_acc',
#        '6_Domain_begin', '7_Domain_end', '8_Domain_length',
#        '9_Largest_insert_length', '10_PDB_validation',
#        '11_Conformational_state', '12_Dihedral_state', '13_Group_in_Uni',
#        '14_Group_in_Manning', '15_Synonymn'],
#       dtype='object')
# ...
