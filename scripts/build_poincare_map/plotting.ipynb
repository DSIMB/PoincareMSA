# %%
import pandas as pd
from pplots import read_embeddings, plot_embedding

# %matplotlib inline

# %%
path_annotation = '/Users/klanna/UniParis/PoincareMSA/examples/thioredoxins/annotation.csv'
path_embedding = '/Users/klanna/UniParis/results/thioredoxins/fasta0.9/PM3sigma=1.00gamma=1.00cosinepca=0_seed0.csv'

# %%
df = read_embeddings(path_annotation, path_embedding)
df.head()
# Out:
#                   pm1       pm2          Species
# proteins_id
# 42           0.899695 -0.325122           Pichia
# 115          0.313596  0.420890       Chlorobium
# 170         -0.615682  0.436858     Bdellovibrio
# 196         -0.955678  0.260758     Thiobacillus
# 19           0.828524 -0.525283  Ornithorhynchus

# %%
# from poincare_maps import plotPoincareDisc

# %%
# import numpy as np
# labels_name = 'Species'
# labels = df['Species'].values

# plotPoincareDisc(
#     df[['pm1', 'pm2']].values, 
#     labels=labels,
#     labels_order=None,
#     title_name='',
#     file_name='./tmp', 
#     d1=5.5, d2=5.0, 
#     bbox=(1.2, 1.),
#     leg=False
#     )

# %%
output_file = '/Users/klanna/UniParis/results/thioredoxins/fasta0.9/species.png'

plot_embedding(
    df,
    labels_name='Species',
    labels_text='all',
    show_text=True,
    title='example',
    file_name=output_file,
    plot_legend=False
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_0/s1psjq8s205_7939yryr3jn80000gn/T/ipykernel_17628/745032503.py in <module>
#       8     title='example',
#       9     file_name=output_file,
# ---> 10     plot_legend=False
#      11     )
#
# ~/UniParis/PoincareMSA/scripts/build_poincare_map/pplots.py in plot_embedding(df, labels, labels_text, labels_idx, col_dict, title, show_lines, show_text, show_legend, axis_equal, circle_size, circe_transparency, line_transparency, line_width, fontsize, fig_width, fig_height, file_name, file_format, labels_name, width_ratios, bbox, plot_legend, is_hyperbolic)
#     175             texts,
#     176             arrowprops=dict(arrowstyle='-', color='black', lw=0.1),
# --> 177             ax=ax
#     178         )
#     179
#
# ...

# %%
from model import poincare_root, poincare_translation

idx_root = 10
embeddings = df[['pm1', 'pm2']].values
poincare_coord_rot = poincare_translation(-embeddings[idx_root, :], embeddings)

# %%
df_rot = df.copy()

# %%
plot_embedding(
    df,
    labels_name='Species',
    labels_text='all',
    show_text=False,
    title='example',
    file_name=output_file,
    plot_legend=True
    )
# Out:
# /Users/klanna/UniParis/PoincareMSA/scripts/build_poincare_map/pplots.py:191: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# Saved file to: /Users/klanna/UniParis/results/thioredoxins/fasta0.9/species.png
# <module 'matplotlib.pyplot' from '/Users/klanna/miniconda3/envs/msa/lib/python3.7/site-packages/matplotlib/pyplot.py'>
